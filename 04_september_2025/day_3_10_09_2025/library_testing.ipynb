# %%
import sklearn
print("scikit-learn is successfully imported!")
print("Version:", sklearn.__version__)
# Out:
# scikit-learn is successfully imported!
# Version: 1.7.2

# %%
import pandas

# %%
data={"team":["csk","rcb","rr"]}
df=pandas.DataFrame(data)

# %%
print(df)
# Out:
#   team
# 0  csk
# 1  rcb
# 2   rr
