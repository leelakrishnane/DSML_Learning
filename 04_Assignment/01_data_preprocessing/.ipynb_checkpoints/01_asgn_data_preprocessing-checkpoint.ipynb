# %%
import pandas as pd
df = pd.read_csv("loan_approval_data_2025.csv")

# %%
df.info()
df.describe(include='all')
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   customer_id              50000 non-null  object
#  1   age                      50000 non-null  int64
#  2   occupation_status        50000 non-null  object
#  3   years_employed           50000 non-null  float64
#  4   annual_income            50000 non-null  int64
#  5   credit_score             50000 non-null  int64
#  6   credit_history_years     50000 non-null  float64
#  7   savings_assets           50000 non-null  int64
#  8   current_debt             50000 non-null  int64
#  9   defaults_on_file         50000 non-null  int64
#  10  delinquencies_last_2yrs  50000 non-null  int64
#  11  derogatory_marks         50000 non-null  int64
#  12  product_type             50000 non-null  object
#  13  loan_intent              50000 non-null  object
# ...

# %% [raw]
# Considering the below aspects based on the above line:
# Numerical: income, loan_amount, credit_score, dti, interest_rate
# Categorical: employment_type, loan_purpose, education, home_ownership
# Binary categorical: bankruptcies, default_history
# Dates: application_date, approval_date
# Text fields: employer_name, address
# Target: loan_status (Approved/Rejected)

# %%
df.isnull().sum()
#no null values are identified, so proceeding with the next step
# If i come across any null values then I would be using the below steps:
# df.dropna(inplace=True)
#below code is to fill the generic values
#df.fillna(1000, inplace=True)
"""below code is to fill specific value (forward filling- if a row exist earlier to this row that value will be filled in below row)"""
# df.ffill(inplace=True)
"""below code is to fill specific value (backward filling- if a row exist below to this row that value will be filled in above row)"""
#df.bfill(inplace=True)
"""Filling the empty cells with specific data on certain columns"""
#df['current_debt'] = df['carat'].fillna(0.25)
"""Filling the empty cells with specific data on multiple columns with calculation"""
#df[['customer_id','age']] = df[['customer_id','age']].fillna(df['loan_status'].mean())
#Simple Imputer can also be implemented for null values

# num_imputer = SimpleImputer(strategy='median')
# df[numerical_cols] = num_imputer.fit_transform(df[numerical_cols])
#Simple Imputer for Categorical values

# cat_imputer = SimpleImputer(strategy='most_frequent')
# df[categorical_cols] = cat_imputer.fit_transform(df[categorical_cols])
# Out:
# customer_id                0
# age                        0
# occupation_status          0
# years_employed             0
# annual_income              0
# credit_score               0
# credit_history_years       0
# savings_assets             0
# current_debt               0
# defaults_on_file           0
# delinquencies_last_2yrs    0
# derogatory_marks           0
# product_type               0
# loan_intent                0
# loan_amount                0
# interest_rate              0
# debt_to_income_ratio       0
# loan_to_income_ratio       0
# payment_to_income_ratio    0
# loan_status                0
# dtype: int64

# %% [raw]
# Null data is completed. Going ahead with Encoding of categorical data
# Below are the data that need to be worked on

# %%
Numerical: income, loan_amount, credit_score, dti, interest_rate
Categorical: employment_type, loan_purpose, education, home_ownership
Binary categorical: bankruptcies, default_history
Dates: application_date, approval_date
Text fields: employer_name, address
Target: loan_status (Approved/Rejected)
